# %% [markdown]
# Segmentation free

# %%
import os
import subprocess
import scanpy as sc
import pandas as pd

# %%
### directory & filepaths
data_dir = '/home/shamini/data1/data_orig/data/spatial/xenium/10xGenomics/cell_seg_brain_cancer/'
out = '/home/shamini/data/projects/spatial_workshop/out/'
os.makedirs(out+'module6/script06_figures/', exist_ok=True)
os.makedirs(out+'module6/script06_objects/segmentation/', exist_ok=True)
os.makedirs(out+'module6/script06_objects/ncv/', exist_ok=True)
os.makedirs(out+'module6/script06_objects/segmentation_with_cell_centers/', exist_ok=True)

# %%
adata_crop = sc.read_h5ad(out+"module6/adata_crop.h5ad")

# %%
adata_crop

### downsample transcripts_df

transcripts_df = pd.read_csv(out+'module6/transcripts_subset_all_genes.csv')

# %%
cell_centers = adata_crop.uns['spatial']
cell_centers

transcripts_df_downsampled = transcripts_df.sample(frac=0.001)
transcripts_df_downsampled.to_csv(out+'module6/script06_objects/transcripts_df_downsampled.csv', index=False)
cell_centers_downsampled = cell_centers[cell_centers.index.isin(transcripts_df_downsampled['cell_id'])]
cell_centers_downsampled.to_csv(out+'module6/script06_objects/cell_centers_downsampled.csv', index=False)

# %%
# Define the Baysor command with the --save-polygons flag

# get filtered transcript files
### Read in the transcripts_df.csv file from module 2

command = [
        '/home/shamini/baysor/bin/baysor/bin/baysor', 'run',
        '-c', '/home/shamini/data/projects/spatial_workshop/scripts/module6/parameters_baysor.toml',
        '-s', '9',
        '--save-polygons', 'geojson',
        '-o', os.path.join(out, 'module6/script06_objects/segmentation/'),
        os.path.join(out,'module6/script06_objects/transcripts_df_downsampled.csv')
        ]
subprocess.run(command, check=True)
# Out:
# [04:13:27] Info: Run Rb1d7ec66e
# [04:13:27] Info: (2024-06-30) Run Baysor v0.6.2
# [04:13:27] Info: Loading data...
# [04:13:29] Info: Loaded 1503 transcripts
# [04:13:31] Info: Estimating noise level
# [04:13:33] Info: Done
# [04:13:47] Info: Clustering molecules...
# [04:13:48] Warning: ICA did not converge, fall back to random initialization
# └ Baysor.Processing /home/viktor_petukhov/.julia/dev/Baysor/src/processing/bmm_algorithm/molecule_clustering.jl:147
# [04:13:49] Info: Algorithm stopped after 21 iterations. Error: 5.04e-5. Converged: true.
# [04:13:49] Info: Done
# [04:13:49] Info: Initializing algorithm. Scale: 9.0, scale std: 2.25, initial #components: 120, #molecules: 1503.
# [04:13:49] Info: Using the following additional information about molecules: [:confidence, :cluster]
# [04:13:49] Info: Using 3D coordinates
# Progress:  85%|██████████████████████████████████▉      |  ETA: 0:00:00
#   Iteration:        23
#   Noise level, %:   32.27
# um. components:  0
#
#
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   Iteration:        27
#   Noise level, %:   32.07
#   Num. components:  0
# [04:13:50] Info: Processing complete.
# [04:13:50] Info: Estimating local colors
# [04:14:04] Warning: n=1503, which is > length(high_conf_ids) (1474)
# └ Baysor.Processing /home/viktor_petukhov/.julia/dev/Baysor/src/processing/data_processing/initialization.jl:180
# [04:14:17] Info: Estimating boundary polygons
# [04:14:17] Warning: To many values of z. Using 2D polygons
# └ Baysor.Processing /home/viktor_petukhov/.julia/dev/Baysor/src/processing/data_processing/boundary_estimation.jl:143
# [04:14:17] Info: Saving results to /home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/segmentation/segmentation.csv
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# [04:14:24] Info: All done!
# CompletedProcess(args=['/home/shamini/baysor/bin/baysor/bin/baysor', 'run', '-c', '/home/shamini/data/projects/spatial_workshop/scripts/module6/parameters_baysor.toml', '-s', '9', '--save-polygons', 'geojson', '-o', '/home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/segmentation/', '/home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/transcripts_df_downsampled.csv'], returncode=0)

# %%
command = [
        '/home/shamini/baysor/bin/baysor/bin/baysor', 'segfree',
        '-c', '/home/shamini/data/projects/spatial_workshop/scripts/module6/parameters_baysor.toml',
        '-o', os.path.join(out, 'module6/script06_objects/ncv/'),
        os.path.join(out,'module6/script06_objects/transcripts_df_downsampled.csv')
        ]
subprocess.run(command, check=True)
# Out:
# [04:14:33] Info: Run R4dfe4183a
# [04:14:33] Info: # CLI params: `-c /home/shamini/data/projects/spatial_workshop/scripts/module6/parameters_baysor.toml -o /home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/ncv/ /home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/transcripts_df_downsampled.csv`
# [04:14:33] Info: (2024-06-30) Run Baysor v0.6.2
# [04:14:33] Info: Loading data...
# [04:14:35] Info: Loaded 1503 transcripts
# [04:14:36] Info: Estimating neighborhoods...
# [04:14:36] Info: Estimating molecule confidences...
# [04:14:37] Info: Estimating gene colors...
# [04:14:57] Warning: n=1503, which is > length(high_conf_ids) (1474)
# └ Baysor.Processing /home/viktor_petukhov/.julia/dev/Baysor/src/processing/data_processing/initialization.jl:180
# [04:15:09] Info: Saving results...
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
# [04:15:14] Info: Done!
# CompletedProcess(args=['/home/shamini/baysor/bin/baysor/bin/baysor', 'segfree', '-c', '/home/shamini/data/projects/spatial_workshop/scripts/module6/parameters_baysor.toml', '-o', '/home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/ncv/', '/home/shamini/data/projects/spatial_workshop/out/module6/script06_objects/transcripts_df_downsampled.csv'], returncode=0)

# %%
#### load baysor output
baysor_seg = pd.read_csv(out+'module6/script06_objects/segmentation/segmentation.csv')

# %%
baysor_seg
# Out:
#       Unnamed: 0    transcript_id     cell_id  overlaps_nucleus     gene  \
# 0      161376389  282462819813394  jpaamlpc-1                 0  SPARCL1
# 1      170285965  281513632243259  joffddop-1                 0   TUBA1B
# 2      164489968  282467114474721  amnedlkf-1                 0    STAT3
# 3      161356570  282462819672451  jhacgahf-1                 1  SPARCL1
# 4      167088718  282467114626591  jplafcde-1                 1     CD74
# ...          ...              ...         ...               ...      ...
# 1498   164455770  282467114235027  jpidnilh-1                 1     ACTB
# 1499   169982721  282471409232755  jlmgchdh-1                 1   SLC1A3
# 1500   170239015  281513631691370  jliemifl-1                 1     EGFR
# 1501   164538243  282467114832449  jphghcei-1                 1   CDKN2C
# 1502   167325200  281509336884920  jkejfgfh-1                 0    ARPC5
#
#                x          y          z         qv fov_name  nucleus_distance  \
# 0      365.15625   878.8574  19.536585  10.535770      Z17          2.188293
# 1     4032.10550  3725.6094  23.619045  40.000000     AA19          0.581290
# 2     2163.27730  1525.0566  23.228128  40.000000      Z18          1.907755
# 3      326.72656  1168.2207  24.124050  40.000000      Z17          0.000000
# 4     3140.55080  1123.8848  21.005756  40.000000      Z18          0.000000
# ...          ...        ...        ...        ...      ...               ...
# 1498  1719.72270  1464.1309  23.411846  39.587856      Z18          0.000000
# 1499  4192.46880  1692.1914  26.176071  40.000000      Z19          0.000000
# 1500  4538.48440  3934.4688  23.799513  23.529787     AA19          0.000000
# 1501  1944.68750  1260.3848  21.475980  18.697315      Z18          0.000000
# 1502  2799.04690  2524.8320  22.975636  40.000000     AA18          0.885713
#
#       codeword_index  molecule_id  confidence  cluster             cell  \
# 0                378            1         1.0        9              NaN
# 1                185            2         1.0        1  CRb1d7ec66e-162
# 2                179            3         1.0        1  CRb1d7ec66e-192
# 3                378            4         1.0        2   CRb1d7ec66e-57
# 4                364            5         1.0        1  CRb1d7ec66e-260
# ...              ...          ...         ...      ...              ...
# 1498             373         1499         1.0        1              NaN
# 1499             216         1500         1.0        1   CRb1d7ec66e-38
# 1500              94         1501         1.0        2  CRb1d7ec66e-217
# 1501               0         1502         1.0        9              NaN
# 1502             213         1503         1.0        1  CRb1d7ec66e-129
#
#       assignment_confidence  is_noise ncv_color
# 0                   0.66667      True   #0077A6
# 1                   1.00000     False   #408594
# 2                   1.00000     False   #00A100
# 3                   1.00000     False   #0078B5
# 4                   1.00000     False   #00A455
# ...                     ...       ...       ...
# 1498                1.00000      True   #009A81
# 1499                1.00000     False   #6C8D5D
# 1500                1.00000     False   #009DBE
# 1501                0.66667      True   #007A4C
# 1502                0.66667     False   #007B57
#
# [1503 rows x 19 columns]

# %%
print(f" Baysor segmentation results in {baysor_seg['cell_id'].nunique()} number of uique cells")
print(f" Original number of cells in the downsampled transcript file is {transcripts_df_downsampled['cell_id'].nunique()}")
# Out:
#  Baysor segmentation results in 1182 number of uique cells
#  Original number of cells in the downsampled transcript file is 1529

# %%
### subset the same genes as before , PTPCR, ANXA1, STMN1

genes = ['PTPRC', 'ANXA1', 'STMN1']
baysor_seg_genes = baysor_seg[baysor_seg['gene'].isin(genes)]
baysor_seg_genes.head(10)
# Out:
#      Unnamed: 0    transcript_id     cell_id  overlaps_nucleus   gene  \
# 30    170288686  281513632250980  jlgdpmln-1                 0  STMN1
# 31    169868892  282471409328081  jloaclbb-1                 0  STMN1
# 53    167318505  281509336839293  jkeaphmg-1                 1  STMN1
# 61    169919658  282471409874279  jlclcakp-1                 1  STMN1
# 94    161570125  281505041666840  jkceplfn-1                 1  ANXA1
# 195   167040538  282467114291552  jljmlhal-1                 1  STMN1
# 202   167185181  282467114390393  jpkbpgin-1                 0  STMN1
# 217   164520737  282467114697534  jphhgaon-1                 1  STMN1
# 256   161450931  282462819382327  jgibdlce-1                 1  ANXA1
# 273   161405120  282462820009886  UNASSIGNED                 0  STMN1
#
#               x           y          z         qv fov_name  nucleus_distance  \
# 30   4678.37100  4585.75800  24.801740  40.000000     AA19          0.291992
# 31   4382.53500   638.55664  22.475628  40.000000      Z19          1.055136
# 53   2711.62500  2441.72660  21.385849  40.000000     AA18          0.000000
# 61   4701.07400  1076.81050  24.665497  21.592703      Z19          0.000000
# 94    711.52344  2459.73630  22.572563  40.000000     AA17          0.000000
# 195  3459.95700   625.56836  24.879513  27.992680      Z18          0.000000
# 202  2708.38670  1283.14060  23.102010  40.000000      Z18          1.487329
# 217  2296.15230  1435.29880  20.897295  40.000000      Z18          0.000000
# 256   293.65234  2092.77540  20.351965  23.087343      Z17          0.000000
# 273   168.21094  1042.07810  19.839382  40.000000      Z17          6.684786
#
#      codeword_index  molecule_id  confidence  cluster             cell  \
# 30              345           31     0.00027        2              NaN
# 31              345           32     1.00000        2  CRb1d7ec66e-200
# 53              345           54     1.00000        2  CRb1d7ec66e-282
# 61              345           62     0.95469        2              NaN
# 94              336           95     1.00000        9   CRb1d7ec66e-11
# 195             345          196     1.00000        2              NaN
# 202             345          203     1.00000        2  CRb1d7ec66e-108
# 217             345          218     1.00000        2  CRb1d7ec66e-277
# 256             336          257     1.00000        7  CRb1d7ec66e-176
# 273             345          274     1.00000        2  CRb1d7ec66e-126
#
#      assignment_confidence  is_noise ncv_color
# 30                     1.0      True   #00A442
# 31                     1.0     False   #0DFFA6
# 53                     1.0     False   #007B59
# 61                     1.0      True   #1AFDA2
# 94                     1.0     False   #005000
# 195                    1.0      True   #00C078
# 202                    1.0     False   #00A129
# 217                    1.0     False   #00A403
# 256                    1.0     False   #005B00
# 273                    1.0     False   #0079B5

# %%
cells_stmn1 = baysor_seg_genes['cell_id'][baysor_seg_genes['gene']=='STMN1'].unique()
cells_anxa1 = baysor_seg_genes['cell_id'][baysor_seg_genes['gene']=='ANXA1'].unique()
cells_ptprc = baysor_seg_genes['cell_id'][baysor_seg_genes['gene']=='PTPRC'].unique()

### cells expressing all 3 genes
cells_all = set(cells_stmn1) & set(cells_anxa1) & set(cells_ptprc)

### cells expressing stmn1 & anxa1
cells_stmn1_anxa1 = set(cells_stmn1) & set(cells_anxa1)

### cells expressing stmn1 & ptprc
cells_stmn1_ptprc = set(cells_stmn1) & set(cells_ptprc)

### cells expressing anxa1 & ptprc
cells_anxa1_ptprc = set(cells_anxa1) & set(cells_ptprc)

print(f" Number of cells expressing all 3 genes is {len(cells_all)}")
print(f" Number of cells expressing STMN1 and ANXA1 is {len(cells_stmn1_anxa1)}")
print(f" Number of cells expressing STMN1 and PTPRC is {len(cells_stmn1_ptprc)}")
print(f" Number of cells expressing ANXA1 and PTPRC is {len(cells_anxa1_ptprc)}")

### print cells expressing single genes
print(f" Number of cells expressing STMN1 is {len(cells_stmn1)}")
print(f" Number of cells expressing ANXA1 is {len(cells_anxa1)}")
print(f" Number of cells expressing PTPRC is {len(cells_ptprc)}")
# Out:
#  Number of cells expressing all 3 genes is 0
#  Number of cells expressing STMN1 and ANXA1 is 0
#  Number of cells expressing STMN1 and PTPRC is 0
#  Number of cells expressing ANXA1 and PTPRC is 0
#  Number of cells expressing STMN1 is 31
#  Number of cells expressing ANXA1 is 9
#  Number of cells expressing PTPRC is 0

# %%
### repeat with baysor cell centers
cells_stmn1_b = baysor_seg_genes['cell'][baysor_seg_genes['gene']=='STMN1'].unique()
cells_anxa1_b = baysor_seg_genes['cell'][baysor_seg_genes['gene']=='ANXA1'].unique()
cells_ptprc_b = baysor_seg_genes['cell'][baysor_seg_genes['gene']=='PTPRC'].unique()

### cells expressing all 3 genes
cells_all_b = set(cells_stmn1_b) & set(cells_anxa1_b) & set(cells_ptprc_b)

### cells expressing stmn1 & anxa1
cells_stmn1_anxa1_b = set(cells_stmn1_b) & set(cells_anxa1_b)

### cells expressing stmn1 & ptprc
cells_stmn1_ptprc_b = set(cells_stmn1_b) & set(cells_ptprc_b)

### cells expressing anxa1 & ptprc
cells_anxa1_ptprc_b = set(cells_anxa1_b) & set(cells_ptprc_b)

print(f" Number of cells expressing all 3 genes is {len(cells_all_b)}")
print(f" Number of cells expressing STMN1 and ANXA1 is {len(cells_stmn1_anxa1_b)}")
print(f" Number of cells expressing STMN1 and PTPRC is {len(cells_stmn1_ptprc_b)}")
print(f" Number of cells expressing ANXA1 and PTPRC is {len(cells_anxa1_ptprc_b)}")

### print cells expressing single genes
print(f" Number of cells expressing STMN1 is {len(cells_stmn1_b)}")
print(f" Number of cells expressing ANXA1 is {len(cells_anxa1_b)}")
print(f" Number of cells expressing PTPRC is {len(cells_ptprc_b)}")
# Out:
#  Number of cells expressing all 3 genes is 0
#  Number of cells expressing STMN1 and ANXA1 is 1
#  Number of cells expressing STMN1 and PTPRC is 0
#  Number of cells expressing ANXA1 and PTPRC is 0
#  Number of cells expressing STMN1 is 26
#  Number of cells expressing ANXA1 is 9
#  Number of cells expressing PTPRC is 0

# %%
### old and new segmentation files

import json

with open(out+'module6/script06_objects/segmentation/segmentation_polygons.json') as f:
    baysor_boundaries = json.load(f)

orig_boundaries = pd.read_csv(out+'module6/cell_boundaries_subset.csv')

# %%
### plotting the segmentation results
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

fig, ax = plt.subplots(1, 2, figsize=(10, 10))

### plot the original segmentation

grouped = orig_boundaries.groupby('cell_id')

for cell_id, group in grouped:
    group = pd.concat([group, group.iloc[[0:1]]])
    plg = Polygon(group[['x', 'y']].values, edgecolor='black', facecolor='none')
    ax[0].add_patch(plg)
    
ax[0].set_title('Original segmentation')


### now plot tje baysor segmentation which is a json file

# %%
baysor_seg
